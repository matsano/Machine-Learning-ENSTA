# %% [markdown]
# # **PROJET MI201**
# ## **Several code snippets for the pizza project**
#
# *Arthur Coelho Ruback* </br>
# *Gustavo Jodar Soares* </br>
# *Matheus Santos Sano* </br>
# </br>
# This notebook was written in English, because the notebook given by the professor was already in English. </br>
# </br>
# The goal of the project is to implement a learning approach capable to identify the toppings of a pizza, using real and synthetic data. The synthetic data is composed by pizza drawings, while the real one is real pizzas.
# The data can be downloaded from the page: http://pizzagan.csail.mit.edu/

# %% [markdown]
# ## 1) Connection to your drive

# %%
from google.colab import drive

drive.mount('/content/gdrive/')

DATA_DIR =  '/content/gdrive/MyDrive/Colab Notebooks/MI201/projet'
# Out:
# Drive already mounted at /content/gdrive/; to attempt to forcibly remount, call drive.mount("/content/gdrive/", force_remount=True).

# %% [markdown]
# ## 2) Useful libraries
#
# To do a convolutional neural network (CNN) we use the library "pytorch".

# %%
import pandas as pd
import numpy as np
import os
import time
import matplotlib.pyplot as plt
from PIL import Image

from tqdm import tqdm

import seaborn as sns
sns.set_style('darkgrid')

#import shutil

import sys
if not sys.warnoptions:
    import warnings
    warnings.simplefilter("ignore")

# scikitlearn
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from sklearn.model_selection import train_test_split

# Pytorch
import torch
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision
import torchvision.transforms as transforms
from torchvision import models
from torch.optim import lr_scheduler
import torch.nn.functional as F
import torch.nn as nn

#!pip install torchmetrics
#from torchmetrics.classification import MultilabelF1Score, MultilabelAccuracy

device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

if (torch.cuda.is_available()):
  # !nvidia-smi
# Out:
# Wed Jan 25 16:47:57 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 510.47.03    Driver Version: 510.47.03    CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   36C    P8    11W /  70W |      3MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# ## 3) Managing data

# %% [markdown]
# ### 3.1) Decompress the archive on Gdrive (rather than on your own desktop)
# Uncomment the following line to do it.

# %%
# !unzip '/content/gdrive/MyDrive/Colab Notebooks/MI201/projet/pizzaGANsyntheticdata.zip' -d '/content/gdrive/MyDrive/Colab Notebooks/MI201/projet'
# Out:
# Le flux de sortie a été tronqué et ne contient que les 5000 dernières lignes.
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3918.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4100.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2272.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3432.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3840.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3395.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0955.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0527.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0280.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1367.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4439.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3053.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2613.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4058.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1706.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0146.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0197.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0630.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4089.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1070.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2165.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3082.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3725.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1863.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1411.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0984.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0251.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3891.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3344.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2504.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2976.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0714.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1154.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2041.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3601.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1535.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1947.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1292.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0375.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3260.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2852.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2420.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2387.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2883.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2356.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3964.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3516.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0403.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0871.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1996.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1243.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3177.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2090.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2737.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1185.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1622.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0062.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0929.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4445.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4837.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4783.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4024.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3788.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2119.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3759.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4752.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3338.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2578.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4333.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4494.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1153.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0713.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3606.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2046.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0372.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1295.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1940.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1532.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2380.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2427.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2855.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3267.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3511.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3963.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2351.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2884.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1244.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4968.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1991.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0876.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0404.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2730.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2097.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3170.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0065.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1625.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1182.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4830.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4442.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3449.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2209.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4023.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4784.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2668.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3028.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4755.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3498.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4493.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4334.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1818.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4671.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1688.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2829.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4210.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1238.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4566.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4914.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0478.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0019.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4107.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1659.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3392.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3847.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3435.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2275.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4399.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1360.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0287.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0520.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0952.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2614.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3054.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0141.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1701.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1077.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4729.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0637.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0190.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3722.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3085.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2162.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0256.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0983.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4348.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1416.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1864.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2971.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2503.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3343.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3896.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2048.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3608.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4603.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3269.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2429.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4262.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0878.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4514.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4966.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4175.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2099.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2207.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3835.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3447.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0552.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0920.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1312.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3026.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3781.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2666.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1773.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0133.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0694.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0645.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1005.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2110.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3750.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1464.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1816.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0583.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0224.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3496.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3331.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2903.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2571.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0761.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1121.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1686.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2034.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2793.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3674.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1932.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1540.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0300.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3215.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2455.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2827.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2484.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2323.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3563.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3911.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0804.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0476.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1591.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1236.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4568.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3102.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2742.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4109.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1657.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0017.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0289.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4397.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4842.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4430.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3849.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4051.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0639.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1079.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4727.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4080.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3898.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4346.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1418.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4893.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0258.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1681.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1126.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4678.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0766.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3673.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2794.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2033.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0307.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4219.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1547.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1935.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2820.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2452.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3212.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3916.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3564.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2324.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2483.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1231.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1596.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0471.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0803.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2745.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3105.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0010.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1650.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1369.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4437.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4845.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4390.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0529.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0148.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4056.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1708.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4087.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4720.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0199.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2978.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4894.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4341.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4604.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2389.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4265.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1949.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1998.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4961.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4513.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3518.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2358.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4172.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2739.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3179.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3440.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3832.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2200.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1315.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4839.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0927.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0555.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2661.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3786.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3021.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0693.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0134.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1774.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1002.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0642.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3757.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2117.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0223.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0584.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1811.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1463.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2576.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2904.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3336.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3491.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4731.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4096.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0188.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4350.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4885.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2969.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4381.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1378.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4854.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4426.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0538.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0159.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4047.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1719.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1587.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1220.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0812.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0460.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3575.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3907.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2492.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2335.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0001.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1641.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2754.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3114.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3662.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2022.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2785.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1137.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4669.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1690.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0777.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2443.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2831.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3203.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0316.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4208.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1924.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1556.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3746.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2106.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1013.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0653.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2915.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2567.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3480.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3327.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0595.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0232.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1472.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1800.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1304.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4828.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0544.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0936.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3823.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3451.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2211.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0125.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0682.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1765.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2670.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3030.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3797.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3509.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2349.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4502.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4970.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1989.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2728.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3168.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4163.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4615.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4274.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1958.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2398.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2101.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3741.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0654.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1014.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3320.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3487.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2560.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2912.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1807.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1475.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0235.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0592.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0931.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0543.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1303.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2216.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3456.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3824.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1762.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0685.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0122.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3790.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3037.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2677.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0869.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4505.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2088.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4164.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4612.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2059.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3619.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4273.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3278.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2438.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0628.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4091.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1068.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4736.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4882.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4357.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1409.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0249.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3889.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3858.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0298.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4421.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4853.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4386.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4040.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0467.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0815.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1227.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4579.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1580.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2332.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2495.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3900.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3572.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/4118.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/1646.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0006.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3113.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2753.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2782.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/2025.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/3665.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images/0770.png
# ...
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0299_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0382_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0069_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0094_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0310_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0034_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0322_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0239_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0319_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0417_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0202_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0114_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0230_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0425_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0126_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0149_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0052_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0473_5.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0344_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0478_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0186_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0290_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0485_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0060_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0376_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0247_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0452_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0168_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0496_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0288_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0163_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0460_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0275_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0085_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0078_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0393_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0301_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0223_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0017_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0404_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0333_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0228_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0398_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0073_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0365_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0496_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0168_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0283_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0041_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0357_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0459_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0436_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0223_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0301_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0135_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0338_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0211_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0404_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0107_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0202_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0036_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0209_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0312_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0004_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0126_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0096_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0380_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0149_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0170_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0266_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0473_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0290_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0059_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0142_0.png
#  extracting: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0441_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0254_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0121_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0237_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0422_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0113_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0410_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0205_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0429_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0371_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0145_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0067_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0297_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0482_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0181_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0343_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0055_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0258_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0394_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0369_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0467_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0199_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0272_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0164_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0046_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0284_5.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0362_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0455_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0156_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0139_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0022_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0334_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0132_5.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0010_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0306_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0350_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0199_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0467_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0046_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0164_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0491_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0284_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0279_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0192_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0089_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0362_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0074_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0100_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0216_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0403_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0132_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0431_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0224_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0003_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0315_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0118_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0031_2.png
#  extracting: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0327_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0429_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0253_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0067_4.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0145_3.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0348_0.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0474_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0489_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0177_1.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0387_2.png
#   inflating: /content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/test/stepimages/0091_0.png

# %% [markdown]
# ### 3.2) Read data
#
# From the data obtained, we build the train and test dataset. In this case, 3976 data were separated only for training and 497 data only for testing. Moreover, there are 10 possible toppings in a pizza. It is possible to have more than one topping in one pizza.

# %%
y_all = np.loadtxt(os.path.join(DATA_DIR, 'syntheticDataset/train/trainLabels.txt'))
x_all = np.arange(y_all.shape[0])

# Create train, val and test splits
# x_train and x_val only contain image number (not the raw data)

x_train, x_val, y_train, y_val = train_test_split(x_all, y_all, test_size=0.2, random_state=123)

print(y_train.shape)

y_test = np.loadtxt(os.path.join(DATA_DIR, 'syntheticDataset/test/testLabels.txt'))
x_test = np.arange(y_test.shape[0])

print(y_test.shape)
# Out:
# (3976, 10)
# (497, 10)

# %% [markdown]
# ### 3.3) Store train images in memory
#
# This should make learning faster.

# %%
train_data_path=os.path.join(DATA_DIR, 'syntheticDataset/train')

# Test if the numpy file exists
if (os.path.exists(os.path.join(train_data_path, 'img_data_224.npz'))):
  img_data_tensor = np.load(os.path.join(train_data_path, 'img_data_224.npz'))
  img_all = img_data_tensor['img_data']
else:
  img_all = []
    
  for idx in tqdm(x_all):
      img_name = "{:04d}.png".format(idx+1)
      x = Image.open(os.path.join(train_data_path, 'images', img_name))
      img_all.append(np.array(x.resize((224,224))))

  np.savez_compressed(os.path.join(train_data_path,'img_data_224.npz'), img_data=np.array(img_all))
# Out:
# 100%|██████████| 4971/4971 [00:26<00:00, 186.12it/s]

# %% [markdown]
# ### 3.4) Dataset class

# %%
class myDataset(Dataset):
    """Pizza dataset"""
    
    def __init__(self, x_idx, y, img_path='/content/gdrive/MyDrive/Colab Notebooks/MI201/projet/syntheticDataset/train/images', img_data = None, transform=None):
      """
      Args:
      """
      self.x_idx = x_idx
      self.y = y
      self.img_path = img_path
      self.transform = transform
      self.img_data = img_data     
    
    def __getitem__(self, idx):
      if isinstance(self.img_data,np.ndarray):
        x = Image.fromarray(self.img_data[idx,:,:,:])
      else:
        img_name = "{:04d}.png".format(idx+1)
        x = Image.open(os.path.join(self.img_path, img_name))
      y = self.y[idx,:]
      if self.transform:
          x = self.transform(x)
      y = np.int64(y)
      return x, y
            
    def __len__(self):
        return int(len(self.x_idx))

# %% [markdown]
# ### 3.5) Data loaders
#
# Image processing and setting global variables for batch size, input size, epochs and learning rate.

# %%
batch_size = 25

epochs = 50

input_size = 224

learning_rate = 0.001

normalize = transforms.Normalize(mean=[0.485, 0.456, 0.406],
                                 std=[0.229, 0.224, 0.225])

train_transform = transforms.Compose([transforms.RandomHorizontalFlip(),
                                         transforms.RandomVerticalFlip(),
                                         transforms.ColorJitter(brightness=32. / 255., saturation=0.5),
                                         transforms.Resize(input_size),
                                         transforms.ToTensor(),
                                     normalize])

val_transform = transforms.Compose([transforms.Resize(input_size),
                                    transforms.ToTensor(),
                                   normalize])
        
kwargs = {'num_workers': 2, 'pin_memory': True} if torch.cuda.is_available() else {}

train_data_path=img_path = os.path.join(DATA_DIR, 'syntheticDataset/train/images')

print(x_train[:10])
img_data_train = [img_all[i] for i in x_train]
img_data_train = np.array(img_data_train)

train_set_raw = myDataset(x_train, y_train, img_path=train_data_path, img_data=img_data_train, transform = train_transform)
train_dataloader = DataLoader(train_set_raw, batch_size=batch_size, shuffle=True, **kwargs)


img_data_val = [img_all[i] for i in x_val]
img_data_val = np.array(img_data_val)

val_set_raw = myDataset(x_val, y_val, img_path=train_data_path, img_data=img_data_val, transform = val_transform)
val_dataloader = DataLoader(val_set_raw, batch_size=batch_size, shuffle=False, **kwargs)

test_data_path=img_path = os.path.join(DATA_DIR, 'syntheticDataset/test/images')

test_set_raw = myDataset(x_test, y_test, img_path=test_data_path, transform = val_transform)
test_dataloader = DataLoader(test_set_raw, batch_size=batch_size, shuffle=False, **kwargs)
# Out:
# [3077 4919 3637 4621 2243 3608 2256 1084 3676  827]

# %% [markdown]
# ## 4) Learning
#
# In this case, the problem is a multi-label prediction: each image may be characterized by several labels. Therefore, to solve this problem we worked on raw data and build the label predictor directly. </br>
# We did a fine tuning of a pre-learned neural network (ResNet), in other words, use the weights of a trained neural network to initialize a new model trained on data from the same images.

# %% [markdown]
# ### 4.1) Network definition
#
# To do a multi-label prediction, we use a residual neural network (ResNet), remove its last layer and rebuild it defining the desired output. In this new last layer, each neuron represents each topping and has 512 inputs and 1 output, being 0 (the pizza does not have this topping) or 1 (the pizza has this topping). The sigmoid function was implemented precisely to approximate the output values to 0 or 1. We decided to use the ResNet to facilitate the learning, because it is a good pre-learned network capable of identifying features. </br>
# Moreover, we use the function Dropout, which droppes out 20% of the nodes in the neural network during training. The Dropout is a solution that we implement to overcome the overfitting problem.

# %%
class MultilabelClassifier(nn.Module):
    def __init__(self):
        super().__init__()
        self.resnet = models.resnet34(pretrained=True)
        self.model_wo_fc = nn.Sequential(*(list(self.resnet.children())[:-1]))

        self.topping0 = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=512, out_features=1)
        )

        self.topping1 = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=512, out_features=1)
        )

        self.topping2 = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=512, out_features=1)
        )

        self.topping3 = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=512, out_features=1)
        )

        self.topping4 = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=512, out_features=1)
        )

        self.topping5 = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=512, out_features=1)
        )

        self.topping6 = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=512, out_features=1)
        )

        self.topping7 = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=512, out_features=1)
        )

        self.topping8 = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=512, out_features=1)
        )

        self.topping9 = nn.Sequential(
            nn.Dropout(p=0.2),
            nn.Linear(in_features=512, out_features=1)
        )

    def forward(self, x):
        x = self.model_wo_fc(x)
        x = torch.flatten(x, 1)
        return torch.stack([torch.sigmoid(self.topping0(x)),
                            torch.sigmoid(self.topping1(x)),
                            torch.sigmoid(self.topping2(x)),
                            torch.sigmoid(self.topping3(x)),
                            torch.sigmoid(self.topping4(x)),
                            torch.sigmoid(self.topping5(x)),
                            torch.sigmoid(self.topping6(x)),
                            torch.sigmoid(self.topping7(x)),
                            torch.sigmoid(self.topping8(x)),
                            torch.sigmoid(self.topping9(x))])

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = MultilabelClassifier().to(device)

# %% [markdown]
# ### 4.2) Training function
#
# The training function implemented iterate over the data, bring them into the neural network and compare the current output to the desired output. Then, it calculate the gradient and update the weights in order to approximate the current output and the desired output. </br>
# In the definition of the learning parameters, the loss function is a cross entropy loss, while the criterion uses binary cross entropy to ensure the binary output of the neural network. </br>
# At each epoch, the losses of training and validation are calculated. The maximum amount of epoches was set to 50. However, when the validation loss increases, the program is terminated. In this way, overfitting is avoided.

# %%
loss_func = nn.CrossEntropyLoss()
criterion = nn.functional.binary_cross_entropy

def training(model,device,lr_rate,epochs,train_loader,val_loader):
  
  num_epochs = epochs
  losses_train = []
  checkpoint_losses_train = []

  losses_val = []
  checkpoint_losses_val = []

  optimizer = torch.optim.Adam(model.parameters(), lr=lr_rate)
  
  n_total_steps = len(train_loader)

  loss_func = nn.CrossEntropyLoss()

  for epoch in range(num_epochs):
    for inputs, targets in train_loader:
      inputs, targets = inputs.to(device),targets.to(device)
      outputs = model(inputs)
      outputs = torch.transpose(outputs, 1, 0)
      outputs = outputs.reshape([len(targets),10])
      outputs = outputs.float()
      
      loss = criterion(outputs.float(), targets.float())
      losses_train.append(loss.item())
      
      optimizer.zero_grad()
      loss.backward()
      optimizer.step()
      
    for inputs, targets in val_loader:
      inputs, targets = inputs.to(device), targets.to(device)
      outputs = model(inputs)
      outputs = torch.transpose(outputs, 1, 0)
      outputs = outputs.reshape([len(targets),10])
      outputs = outputs.float()

      loss = criterion(outputs.float(), targets.float())
      losses_val.append(loss.item())


    checkpoint_loss_train = torch.tensor(losses_train).mean().item()
    checkpoint_loss_val = torch.tensor(losses_val).mean().item()
        
    checkpoint_losses_train.append(checkpoint_loss_train)
    checkpoint_losses_val.append(checkpoint_loss_val)

    print (f'Epoch [{epoch+1}/{num_epochs}], Training Loss: {checkpoint_loss_train:.4f} | Validation Loss: {checkpoint_loss_val:.4f}')
    if(len(checkpoint_losses_val) > 1 and checkpoint_losses_val[-2] <= checkpoint_losses_val[-1]):
      break

  return checkpoint_losses_train, checkpoint_losses_val

# %%
checkpoint_losses_train, checkpoint_losses_val = training(model,device,learning_rate,epochs,train_dataloader, val_dataloader)
# Out:
# Epoch [1/50], Training Loss: 0.3948 | Validation Loss: 0.2966
# Epoch [2/50], Training Loss: 0.3109 | Validation Loss: 0.2526
# Epoch [3/50], Training Loss: 0.2649 | Validation Loss: 0.2297
# Epoch [4/50], Training Loss: 0.2335 | Validation Loss: 0.2053
# Epoch [5/50], Training Loss: 0.2120 | Validation Loss: 0.1861
# Epoch [6/50], Training Loss: 0.1939 | Validation Loss: 0.1772
# Epoch [7/50], Training Loss: 0.1793 | Validation Loss: 0.1661
# Epoch [8/50], Training Loss: 0.1675 | Validation Loss: 0.1585
# Epoch [9/50], Training Loss: 0.1575 | Validation Loss: 0.1515
# Epoch [10/50], Training Loss: 0.1489 | Validation Loss: 0.1448
# Epoch [11/50], Training Loss: 0.1416 | Validation Loss: 0.1398
# Epoch [12/50], Training Loss: 0.1347 | Validation Loss: 0.1352
# Epoch [13/50], Training Loss: 0.1291 | Validation Loss: 0.1308
# Epoch [14/50], Training Loss: 0.1243 | Validation Loss: 0.1278
# Epoch [15/50], Training Loss: 0.1199 | Validation Loss: 0.1239
# Epoch [16/50], Training Loss: 0.1154 | Validation Loss: 0.1204
# Epoch [17/50], Training Loss: 0.1116 | Validation Loss: 0.1176
# Epoch [18/50], Training Loss: 0.1079 | Validation Loss: 0.1152
# Epoch [19/50], Training Loss: 0.1049 | Validation Loss: 0.1130
# Epoch [20/50], Training Loss: 0.1019 | Validation Loss: 0.1105
# Epoch [21/50], Training Loss: 0.0989 | Validation Loss: 0.1085
# Epoch [22/50], Training Loss: 0.0962 | Validation Loss: 0.1070
# Epoch [23/50], Training Loss: 0.0940 | Validation Loss: 0.1052
# Epoch [24/50], Training Loss: 0.0917 | Validation Loss: 0.1038
# Epoch [25/50], Training Loss: 0.0897 | Validation Loss: 0.1022
# Epoch [26/50], Training Loss: 0.0877 | Validation Loss: 0.1009
# Epoch [27/50], Training Loss: 0.0859 | Validation Loss: 0.0995
# Epoch [28/50], Training Loss: 0.0840 | Validation Loss: 0.0984
# Epoch [29/50], Training Loss: 0.0824 | Validation Loss: 0.0980
# Epoch [30/50], Training Loss: 0.0804 | Validation Loss: 0.0970
# Epoch [31/50], Training Loss: 0.0787 | Validation Loss: 0.0959
# Epoch [32/50], Training Loss: 0.0772 | Validation Loss: 0.0949
# Epoch [33/50], Training Loss: 0.0758 | Validation Loss: 0.0937
# Epoch [34/50], Training Loss: 0.0746 | Validation Loss: 0.0928
# Epoch [35/50], Training Loss: 0.0734 | Validation Loss: 0.0917
# Epoch [36/50], Training Loss: 0.0722 | Validation Loss: 0.0908
# Epoch [37/50], Training Loss: 0.0711 | Validation Loss: 0.0909

# %% [markdown]
# ### 4.3) Training analysis - graph
#
# At each epoche, the validation and training losses decrease, approaching zero. This effect, shown in the graph below, reports the good training of the neural network.

# %%
#checkpoint_losses_train, checkpoint_losses_val
x_epochs = []
for i in range(0, len(checkpoint_losses_train)): x_epochs.append(i)


# plotting the points  
#plt.plot(checkpoint_losses_train, y) 
plt.figure(figsize=(10, 8))
plt.plot(x_epochs, checkpoint_losses_train, label="Training Error")  
plt.plot(x_epochs, checkpoint_losses_val, label="Validation Error") 

# naming the x axis 
plt.xlabel('Epochs') 
# naming the y axis 
plt.ylabel('Error') 
    
# giving a title to my graph 
plt.title('Training and validation error per epoch') 
plt.legend(loc=1, )
# function to show the plot 
plt.show()

# %% [markdown]
# ### 4.4) Test analysis - images
#
# Below, there are some test images and their respective labels, that the neural network predicted. When a topping has been identified, the output value is 1. Otherwise, it is 0. </br>
# For example, in the first pizza, 3 different toppings were identified. On the last image, 5 different ones were labelled.

# %%
for inputs, targets in test_dataloader:
  inputs, targets = inputs.to(device),targets.to(device)
  outputs = treat_output(model(inputs), len(targets))
  f, axarr = plt.subplots(3,3, figsize=(15, 15))
  c = 0
  for i in range(3):
    for j in range(3):
      axarr[i][j].imshow(np.clip(np.array(inputs[c].cpu()).transpose(1,2,0), 0, 1), )
      axarr[i][j].set_title(np.array(outputs[c].cpu().detach()))
      c = c + 1  
  break
# Out:
# /usr/local/lib/python3.8/dist-packages/matplotlib/text.py:1165: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %% [markdown]
# # 5) Final Evaluation
#
# After training, the accuracies are calculated in the testing phase. </br>
# As can be seen, the learning performance varies for each topping, but all are greater than 96%. Therefore, it can be concluded that the learning of the implemented neural network is satisfactory.

# %%
# create the per
perf_label_test = np.zeros((1,10))

# tell not to reserve memory space for gradients (much faster)
with torch.no_grad():
    for inputs, targets in test_dataloader:

        inputs = inputs.to(device)
        targets = targets.to(device)

        # compute outputs
        outputs = model(inputs)
        outputs = torch.transpose(outputs, 1, 0)
        outputs = outputs.reshape([len(targets),10])

        for i in range(0,len(outputs)):
          outputs[i] = torch.round(outputs[i])

        outputs_np = outputs.cpu().detach().numpy()
        targets_np = targets.cpu().detach().numpy()

        # compute the predictions
        pred = (outputs_np > 0)

        # update the performance
        perf_label_test = perf_label_test + (targets_np == pred).sum(axis=0)

# Prints the performance (per label)

oa_test = perf_label_test / len(test_dataloader.dataset)
print(oa_test)
# Out:
# [[0.98591549 0.98792757 0.98189135 0.99597586 0.96981891 0.96780684
#   0.9637827  0.98993964 0.96177062 0.99396378]]

# %% [markdown]
# # 6) Comparison between Real and Synthetic datasets
#
# After coding and solving the problem for the synthetic dataset, we adapted our code to work with the real dataset. The main changes were:
# - Changing the last layer of the network to have 13 outputs instead of 10, since the real dataset has 13 possible toppings. This was a simple task as the last layer of the network was already custom-made by our previous work.
# - The real dataset was organized in one block of data instead of a test and training sets. So, we loaded all the data and used the function train_test_split in a ratio of 80/20 to training and test sets respectively. It is also important to note that the training set has been also split during the training phase for validation purposes as it was done for the synthetic database.
# - Another observation is that there were several images in the real dataset, around 50 located in the interval 3000-4000, that had 4 layers instead of the usual 3 (RGB), so they were treated as to ignore this last layer (transparency layer).
# - As the images of the synthetic pizzas are simple, they are better treated and, thus, the performance with the synthetic dataset is better than the real dataset.
